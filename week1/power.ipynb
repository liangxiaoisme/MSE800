# %%
try:
    x = float(input("Enter the base (x): "))
    y = float(input("Enter the exponent (y): "))

    result = x ** y
    print("Result:", result)
except ValueError:
    print("Error: Please enter valid numbers!")
# Out:
# Enter the base (x):  12
# Enter the exponent (y):  23
# Result: 6.624737266949237e+24
