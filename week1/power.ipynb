# %%
# Week 4 Quantum Computing Tasks
# Requires: qiskit, qiskit-aer, matplotlib

from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_state_qsphere
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt

# ==========================================================
# Task 1:
# Create a 2-qubit quantum circuit with a 90° phase shift
# and visualize it using the Q-sphere.
# ==========================================================

print("=== Task 1: 2-Qubit Circuit with 90° Phase Shift ===")

qc1 = QuantumCircuit(2)

# Put qubit 0 into superposition
qc1.h(0)

# Apply a 90° phase shift (π/2 radians)
qc1.p(3.1415926535 / 2, 0)

# Entangle the two qubits
qc1.cx(0, 1)

print(qc1.draw('mpl'))
plt.show()

# Generate statevector and plot Q-sphere
state = Statevector.from_instruction(qc1)
plot_state_qsphere(state)
plt.show()
# Out:
# === Task 1: 2-Qubit Circuit with 90° Phase Shift ===
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[7], line 29
#      26 # Entangle the two qubits
#      27 qc1.cx(0, 1)
# ---> 29 print(qc1.draw('mpl'))
#      30 plt.show()
#      32 # Generate statevector and plot Q-sphere
#
# File C:\ProgramData\anaconda3\envs\py311\Lib\site-packages\qiskit\circuit\quantumcircuit.py:4040, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#    3895 r"""Draw the quantum circuit. Use the output parameter to choose the drawing format:
#    3896
#    3897 ``text``
#    (...)   4035        qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#    4036 """
#    4038 from qiskit.visualization import circuit_drawer
# -> 4040 return circuit_drawer(
#    4041     self,
#    4042     scale=scale,
#    4043     filename=filename,
#    4044     style=style,
#    4045     output=output,
#    4046     interactive=interactive,
#    4047     plot_barriers=plot_barriers,
#    4048     reverse_bits=reverse_bits,
#    4049     justify=justify,
#    4050     vertical_compression=vertical_compression,
#    4051     idle_wires=idle_wires,
#    4052     with_layout=with_layout,
#    4053     fold=fold,
#    4054     ax=ax,
#    4055     initial_state=initial_state,
#    4056     cregbundle=cregbundle,
#    4057     wire_order=wire_order,
#    4058     expr_len=expr_len,
#    4059     barrier_label_len=barrier_label_len,
#    4060     measure_arrows=measure_arrows,
#    4061 )
#
# File C:\ProgramData\anaconda3\envs\py311\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:368, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     352     return _generate_latex_source(
#     353         circuit,
#     354         filename=filename,
#    (...)    365         barrier_label_len=barrier_label_len,
#     366     )
#     367 elif output == "mpl":
# --> 368     image = _matplotlib_circuit_drawer(
#     369         circuit,
#     370         scale=scale,
#     371         filename=filename,
#     372         style=style,
#     373         plot_barriers=plot_barriers,
#     374         reverse_bits=reverse_bits,
#     375         justify=justify,
#     376         idle_wires=idle_wires,
#     377         with_layout=with_layout,
#     378         fold=fold,
#     379         ax=ax,
#     380         initial_state=initial_state,
#     381         cregbundle=cregbundle,
#     382         wire_order=complete_wire_order,
#     383         expr_len=expr_len,
#     384         measure_arrows=measure_arrows,
#     385         barrier_label_len=barrier_label_len,
#     386     )
#     387 else:
#     388     raise VisualizationError(
#     389         f"Invalid output type {output} selected. The only valid choices "
#     390         "are text, latex, latex_source, and mpl"
#     391     )
#
# File C:\ProgramData\anaconda3\envs\py311\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:776, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     773 if fold is None:
#     774     fold = 25
# --> 776 qcd = _matplotlib.MatplotlibDrawer(
#     777     qubits,
#     778     clbits,
#     779     nodes,
#     780     circuit,
#     781     scale=scale,
#     782     style=style,
#     783     reverse_bits=reverse_bits,
#     784     plot_barriers=plot_barriers,
#     785     fold=fold,
#     786     ax=ax,
#     787     initial_state=initial_state,
#     788     cregbundle=cregbundle,
#     789     with_layout=with_layout,
#     790     expr_len=expr_len,
#     791     barrier_label_len=barrier_label_len,
#     792     measure_arrows=measure_arrows,
#     793 )
#     794 return qcd.draw(filename)
#
# File C:\ProgramData\anaconda3\envs\py311\Lib\site-packages\qiskit\utils\classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File C:\ProgramData\anaconda3\envs\py311\Lib\site-packages\qiskit\utils\lazy_tester.py:42, in _RequireNow.__call__(self, *_args, **_kwargs)
#      41 def __call__(self, *_args, **_kwargs):
# ---> 42     self._tester.require_now(self._feature)
#
# File C:\ProgramData\anaconda3\envs\py311\Lib\site-packages\qiskit\utils\lazy_tester.py:222, in LazyDependencyManager.require_now(self, feature)
#     220 if self:
#     221     return
# --> 222 raise MissingOptionalLibraryError(
#     223     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     224 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %%
bash
pip install qiskit qiskit-aer matplotlib
# Out:
#   Cell In[4], line 2
#     pip install qiskit qiskit-aer matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
# Use ! prefix to run shell commands in Jupyter Notebook
# !pip install qiskit qiskit-aer matplotlib

# %%
# Week 4 Quantum Computing Tasks
# Requires: qiskit, qiskit-aer, matplotlib

from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_state_qsphere
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt

# ==========================================================
# Task 1:
# Create a 2-qubit quantum circuit with a 90° phase shift
# and visualize it using the Q-sphere.
# ==========================================================

print("=== Task 1: 2-Qubit Circuit with 90° Phase Shift ===")

qc1 = QuantumCircuit(2)

# Put qubit 0 into superposition
qc1.h(0)

# Apply a 90° phase shift (π/2 radians)
qc1.p(3.1415926535 / 2, 0)

# Entangle the two qubits
qc1.cx(0, 1)

print(qc1.draw('mpl'))
plt.show()

# Generate statevector and plot Q-sphere
state = Statevector.from_instruction(qc1)
plot_state_qsphere(state)
plt.show()

# %%
# !pip install qiskit qiskit-aer matplotlib
# Out:
# Requirement already satisfied: qiskit in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (2.4.1)
# Requirement already satisfied: qiskit-aer in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (0.17.2)
# Requirement already satisfied: matplotlib in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (3.10.9)
# Requirement already satisfied: rustworkx>=0.15.0 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit) (2.4.4)
# Requirement already satisfied: scipy>=1.5 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit) (1.17.1)
# Requirement already satisfied: dill>=0.3 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit) (5.7.0)
# Requirement already satisfied: typing-extensions in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\ProgramData\anaconda3\envs\py311\Lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
